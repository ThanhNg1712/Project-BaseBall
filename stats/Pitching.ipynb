# %%
#cd /Users/thanhnguyen/Desktop/Data_analysis/DE_k2/project1/stats
# Out:
# /Users/thanhnguyen/Desktop/Data_analysis/DE_k2/project1/stats

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
games = pd.read_csv('/Users/thanhnguyen/Desktop/Data_analysis/DE_k2/project1_baseball/games/games.csv')
games
# Out:
#           type         multi2                       multi3 multi4  multi5  \
# 0           id   ALS193307060                          NaN    NaN     NaN
# 1      version              1                          NaN    NaN     NaN
# 2         info  inputprogvers  version 7RS(19) of 07/07/92    NaN     NaN
# 3         info        visteam                          NLS    NaN     NaN
# 4         info       hometeam                          ALS    NaN     NaN
# ...        ...            ...                          ...    ...     ...
# 19043     data             er                     jeffj001      0     NaN
# 19044     data             er                     rivef001      0     NaN
# 19045     data             er                     hadej001      1     NaN
# 19046     data             er                     handb001      0     NaN
# 19047     data             er                     strir001      3     NaN
#
#       multi6 event       game_id  year
# 0        NaN   NaN  ALS193307060  1933
# 1        NaN   NaN  ALS193307060  1933
# 2        NaN   NaN  ALS193307060  1933
# 3        NaN   NaN  ALS193307060  1933
# 4        NaN   NaN  ALS193307060  1933
# ...      ...   ...           ...   ...
# 19043    NaN   NaN  NLS201807170  2018
# 19044    NaN   NaN  NLS201807170  2018
# 19045    NaN   NaN  NLS201807170  2018
# 19046    NaN   NaN  NLS201807170  2018
# 19047    NaN   NaN  NLS201807170  2018
#
# [19048 rows x 9 columns]

# %%
#task1
plays = games[games['type'] == 'play']
plays.head()
# Out:
#     type multi2 multi3    multi4  multi5 multi6   event       game_id  year
# 53  play      1      0  martp103     NaN    NaN      63  ALS193307060  1933
# 54  play      1      0  frisf101     NaN    NaN  63/G6D  ALS193307060  1933
# 55  play      1      0  kleic101     NaN    NaN     6/L  ALS193307060  1933
# 56  play      1      1  chapb102     NaN    NaN      53  ALS193307060  1933
# 57  play      1      1  gehrc101     NaN    NaN       W  ALS193307060  1933

# %%
#task2
strike_outs = plays[plays['event'].str.contains('K')]
strike_outs.head()
# Out:
#      type multi2 multi3    multi4  multi5 multi6    event       game_id  year
# 58   play      1      1  ruthb101    32.0    NaN  K+SB2/C  ALS193307060  1933
# 63   play      2      0  bartd101     NaN    NaN        K  ALS193307060  1933
# 102  play      5      1  gehrl101     NaN    NaN        K  ALS193307060  1933
# 122  play      6      1  ruthb101     NaN    NaN        K  ALS193307060  1933
# 130  play      7      0  hartg103    22.0    NaN        K  ALS193307060  1933

# %%
#task3

strike_outs = strike_outs.groupby(['year', 'game_id']).size()
#task4
strike_outs = strike_outs.reset_index(name='strike_outs')
strike_outs.head()
# Out:
#    year       game_id  strike_outs
# 0  1933  ALS193307060            8
# 1  1934  NLS193407100           17
# 2  1935  ALS193507080           14
# 3  1936  NLS193607070           13
# 4  1937  ALS193707070            7

# %%
#task5
strike_outs = strike_outs.loc[:,['year','strike_outs']].apply(pd.to_numeric)

# %%
#task6
plt.figure(figsize=(15,8))
plt.scatter(strike_outs['year'],strike_outs['strike_outs'])
plt.legend(['Strike Outs'])
plt.show()
